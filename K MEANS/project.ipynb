# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    s_f_ratio  perc_alumni  expend  grad_rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Yes to Yes
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   apps         777 non-null    int64
#  1   accept       777 non-null    int64
#  2   enroll       777 non-null    int64
#  3   top10perc    777 non-null    int64
#  4   top25perc    777 non-null    int64
#  5   f_undergrad  777 non-null    int64
#  6   p_undergrad  777 non-null    int64
#  7   outstate     777 non-null    int64
#  8   room_board   777 non-null    int64
#  9   books        777 non-null    int64
#  10  personal     777 non-null    int64
#  11  phd          777 non-null    int64
#  12  terminal     777 non-null    int64
#  13  s_f_ratio    777 non-null    float64
#  14  perc_alumni  777 non-null    int64
#  15  expend       777 non-null    int64
#  16  grad_rate    777 non-null    int64
# dtypes: float64(1), int64(16)
# memory usage: 109.3+ KB

# %%
df.describe()
# Out:
#                apps        accept       enroll   top10perc   top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         f_undergrad   p_undergrad      outstate   room_board        books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# scatter plot of grad rate vs room board
sns.lmplot(x='room_board',y='grad_rate',data=df,hue='private')

# %%
# dont want these two lines
# scatter plot of grad rate vs room board
sns.lmplot(x='room_board',y='grad_rate',data=df,hue='private',fit_reg=False)

# %%
g=sns.FacetGrid(df,hue='private')
g=g.map(plt.hist,'outstate',bins=23)

# %%
# private school having graduation rate higher than 100
df[df['grad_rate']>100]
# Out:
#    private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 95     Yes  3847    3433     527          9         35         1010
#
#     p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 95           12      9384        4840    600       500   22        47
#
#     s_f_ratio  perc_alumni  expend  grad_rate
# 95       14.3           20    7697        118

# %%
# iska grad rate ab 100 set krdo abhi 118 hai
df['grad_rate'][95]=100
# Out:
# C:\Users\FatimaTasneem\AppData\Local\Temp\ipykernel_12748\1914140939.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['grad_rate'][95]=100
# ...

# %%
df[df['grad_rate']>100]
# Out:
# Empty DataFrame
# Columns: [private, apps, accept, enroll, top10perc, top25perc, f_undergrad, p_undergrad, outstate, room_board, books, personal, phd, terminal, s_f_ratio, perc_alumni, expend, grad_rate]
# Index: []

# %% [markdown]
# # now lets do kmeans

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=2)

# %%
# sb me fit kro except privte wagera m
kmeans.fit(df.drop('private',axis=1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[1.94782101e+03, 1.31368639e+03, 4.86974852e+02, 2.67500000e+01,
#         5.45857988e+01, 2.11855178e+03, 5.43665680e+02, 1.07181509e+04,
#         4.37916420e+03, 5.44346154e+02, 1.26384320e+03, 7.10266272e+01,
#         7.82988166e+01, 1.37792899e+01, 2.37071006e+01, 9.61601627e+03,
#         6.59896450e+01],
#        [1.00549109e+04, 6.73820792e+03, 2.74102970e+03, 3.29702970e+01,
#         6.39009901e+01, 1.42840297e+04, 2.94107921e+03, 8.58346535e+03,
#         4.21270297e+03, 5.83079208e+02, 1.85466337e+03, 8.35940594e+01,
#         8.90990099e+01, 1.61673267e+01, 1.62970297e+01, 9.95570297e+03,
#         6.17623762e+01]])

# %% [markdown]
# # EVALUATION
# ye real life m nhi hota kyu k we've unlabel data we dont know k teek h ya nhi but ye label data tha tou yahan krri hun

# %%
# create new column for df called cluster which is 1 for pvt school and 0 for public
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0

# %%
df['Cluster']=df['private'].apply(converter)

# %%
df.head()
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    s_f_ratio  perc_alumni  expend  grad_rate  Cluster
# 0       18.1           12    7041         60        1
# ...

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(df['Cluster'],kmeans.labels_))
print('\n')
print(classification_report(df['Cluster'],kmeans.labels_))
# Out:
# [[123  89]
#  [553  12]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.18      0.58      0.28       212
#            1       0.12      0.02      0.04       565
#
#     accuracy                           0.17       777
#    macro avg       0.15      0.30      0.16       777
# weighted avg       0.14      0.17      0.10       777

# %%
# not in real life
